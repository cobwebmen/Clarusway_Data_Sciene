# %% [markdown]
# mean (ortalama) median (ortası) mod (en çok tekrar eden)
#
# !! mean + standar deviation (U+Q) !!
# % 68 U + 1Q
# % 95 U + 2Q
# % 99,7 U + 3Q
#
# quartiles %25 %75 = lower fourth and upper fourth
#
# IQR = %75 - %25 = fourth spread Q3 - Q1

# %% [markdown]
# >__Scatter Plot__
#
# x = weight y = Height
#
# two quantitative variables
# scatter plots reveal patterns in bivariate data. iki değişken arasındaki dağılım grafiği.

# %% [markdown]
# >__Patterns of Data__
#
# Linearity = doğrusal ve doğrusal olmayan
#
# Slope = x değişken büyürken y ne yapar? eğim gibi. pozitif ve negatif olarak .
#
# Strength = ilişkinin gücü - yayılım çok heryere dağılmışsa o zaman zayıf bir ilişkin vardır hatta yoktur. ancak doğrusal bir çizgi etrafında toplanmışlarsa o zamanda güçlüdür. 0.85 üzeri genel anlamda güçlü kabul edilir.
#
# Unusual Features = kümelenmeler cluster olarak karşımıza çıkan durumlar. outlier gibi.

# %% [markdown]
# > Box Plot (whisker plot)
#
#
# ![image.png](attachment:c86a10d9-5929-4299-ba86-0d9de2ad9269.png)
#
# Q2 median demek
#
# outlier varsa 1.5 * IQR dışındakilerdir.
# ama ekstreme durumlarda ise 3*IQR dışı olabilir.
#
# ![image.png](attachment:00393c64-a276-4bdb-a51c-55a83fcb92c3.png)
#
# median q3'e yakınsa left skewed deriz. q1'e yakınsa o zamanda right deriz. Ancak whiskerslarda önemlidir ve gözden kaçırmamak gerekir.

# %% [markdown]
# >__covariance__
#
# ![image.png](attachment:08184f91-86c4-4af7-b535-dae681746698.png)
#
#
# cov(x,y)>0 ise aynı yönde değişiyorlar. x artarken y de artar.
#
# <0 ise ters yönde ilişki var. negatif
#
# =0 ise birbirinden bağımsız.

# %% [markdown]
# >__correlation__
#
# ilişkinin yönü (covariance ile elde edebiliyorduk) ve gücü .. direction and strenght
#
# örnekler = sigara ve kanser .. boy ve kilo .. talep fiyat ilişkisi
#
# >(__r__)
#
# Pearson Korelasyon Katsayı
#
# -1 ile +1 arasında değişir. +/- 1'e yakınsa güçlü oluyor. 0'a yakınsa o zaman da zayıf oluyor.
#
# ![image.png](attachment:5e741b21-5f58-41f2-ac36-1db9e9c9b011.png)
