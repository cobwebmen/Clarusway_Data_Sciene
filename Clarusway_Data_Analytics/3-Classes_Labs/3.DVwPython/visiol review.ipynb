# %%
# Basic Library
import numpy as np
import pandas as pd
# Libraries for Visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings;
warnings.filterwarnings('ignore')

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]
salary = [38496, 42000, 46752, 49320, 53200,
         56000, 62316, 64928, 67317, 68748, 73752]
salary_2 = [45372, 48876, 53850, 57287, 63016,
            65998, 70003, 70000, 71496, 75370, 83640]

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),fontsize=18, ha='center')
    plt.title(i)
plt.suptitle("with for loop")
plt.tight_layout()
plt.show()

# %%
x= np.array([15,17,18,17,12,17,12,19,14,11,12,19,16,13])
y= np.array([99,86,87,88,81,86,93,87,94,78,77,85,86,85])
plt.scatter(x,y)
plt.show()

# %%
y= np.random.randint(10,100,50)
x= np.random.randint(10,100,50)
plt.scatter(x,y)
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns

# %%
plt.scatter(tips.total_bill, tips.tip);

# %%
plt.plot(tips.time, tips.sex);

# %%
plt.scatter(tips.time, tips.sex);

# %%
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]

# %%
fig, ax = plt.subplots()

ax.bar(langs, students)
# Out:
# <BarContainer object of 5 artists>

# %%
fig, ax = plt.subplots()

ax.barh(langs, students)
# Out:
# <BarContainer object of 5 artists>

# %%
day = tips.groupby("day").sum().index   # tips.day.unique()
day
# Out:
# CategoricalIndex(['Thur', 'Fri', 'Sat', 'Sun'], categories=['Thur', 'Fri', 'Sat', 'Sun'], ordered=False, name='day', dtype='category')

# %%
day_of_total_bill= list(tips.groupby("day")["total_bill"].sum())
day_of_total_bill
# Out:
# [1096.3299999999997,
#  325.87999999999994,
#  1778.3999999999996,
#  1627.1600000000003]

# %%
fig, ax = plt.subplots()

ax.barh(day, day_of_total_bill);

# %%
tipp = list(tips.groupby('day')['tip'].sum())
tipp

fig, ax = plt.subplots()

ax.bar(day, tipp);

# %%
tipp = list(tips.groupby('day')['tip'].sum())
tipp
# Out:
# [171.83, 51.96, 260.4, 247.39000000000007]

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.bar(day, day_of_total_bill,  label="total_bill")
ax.bar(day, tipp,            label="tip")
plt.legend()

# %%
# Optional hard to coding
fig, ax = plt.subplots(figsize=(10,5))
p = np.arange(len(day))
width = 0.15
ax.bar(p - width/2, day_of_total_bill, width, label="total_bill")
ax.bar(p + width/2, tipp,           width, label="tip")
ax.set_xticks(p)
ax.set_xticklabels(day)
plt.legend()
plt.show()

# %%
x = np.random.randn(250)
plt.hist(x, bins = 45);

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.hist(tips["total_bill"], bins = 30);

# %%
plt.hist(tips["tip"], bins = 40);

# %%
plt.boxplot(tips["tip"]);

# %%
X = np.random.normal(170,10,250)
plt.boxplot(X)
plt.show()

# %%
X = np.random.normal(170,10,250)
plt.boxplot(X, vert=False)
plt.show()

# %%
X = np.random.normal(170,10,250)
plt.boxplot(X, vert = False)
plt.show()

# %%
X = np.random.normal(170,10,250)
plt.boxplot(X, vert =False)
plt.show()

# %%
box = np.array(np.random.rand(10,4))
box
# Out:
# array([[0.62406143, 0.35754664, 0.29025583, 0.61793973],
#        [0.85740533, 0.39414181, 0.27614297, 0.84563211],
#        [0.26694235, 0.78924081, 0.25723074, 0.13821975],
#        [0.34976089, 0.9654648 , 0.1955919 , 0.33495946],
#        [0.7682862 , 0.90323238, 0.71053402, 0.01055798],
#        [0.57597359, 0.65398243, 0.08415294, 0.33434204],
#        [0.16044782, 0.29850636, 0.59569354, 0.49224344],
#        [0.47535996, 0.08835718, 0.25308817, 0.46635171],
#        [0.2040514 , 0.27381209, 0.37137184, 0.58032102],
#        [0.34100336, 0.50555896, 0.56772863, 0.85461887]])

# %%
plt.boxplot(box, labels=['A', 'B', 'C', 'D'])
plt.show()

# %%
plt.boxplot([tips.tip, tips.total_bill], labels=['tatol_bill', 'tip'])
plt.show()

# %%
tips
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
tips.iloc[:,0:2]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
plt.boxplot(tips.iloc[:,0:2],labels=['tatol_bill', 'tip'])
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

# %%
plt.pie(y, labels = mylabels, labeldistance= 0.8, autopct='%0.1i')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.pie(y, labels = mylabels, labeldistance = 0.7, autopct="%.2f")
plt.show()

# %%
plt.figure(figsize=(10,8))
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0, 0.2, 0, 0]

# %%
plt.figure(figsize=(10,8))
plt.pie(y, labels = mylabels, explode = myexplode, labeldistance=0.7, autopct="%.1f")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0, 0, 0.1, 0.1] # ratio for each continent with which to offset each wedge.
y = np.array([14.9, 35, 25, 15])
mylabels = ["Bananas", "Apples", "Cherries", "Dates"]
myexplode = [0.1, 0, 0, 0]
plt.pie(y, labels = mylabels,labeldistance=0.7, autopct="%.2f", startangle=90, shadow=True, pctdistance=1.2, colors=colors_list, explode=explode_list)
plt.legend(loc="best")
plt.show()
